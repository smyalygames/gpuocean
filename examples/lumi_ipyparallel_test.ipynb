# %%
#!export MPICH_GPU_SUPPORT_ENABLED=1
#!export I_MPI_PMI_LIBRARY=pmi2

# %%
# Build container image using "Cotainr": https://docs.lumi-supercomputer.eu/software/containers/singularity/#building-containers-using-the-cotainr-tool

# %%
import sys
sys.path.append("../src")

# %%
import ipyparallel as ipp

def mpi_example():
    from mpi4py import MPI
    comm = MPI.COMM_WORLD
    return f"Hello World from rank {comm.Get_rank()}. total ranks={comm.Get_size()}"

# request an MPI cluster with 4 engines
with ipp.Cluster(engines='mpi', n=4) as rc:
    # get a broadcast_view on the cluster which is best
    # suited for MPI style computation
    view = rc.broadcast_view()
    # run the mpi_example function on all engines in parallel
    r = view.apply_sync(mpi_example)
    # Retrieve and print the result from the engines
    print("\n".join(r))
# at this point, the cluster processes have been shutdown
# Out:
# Starting 4 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
#   0%|          | 0/4 [01:00<?, ?engine/s]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[10], line 9
#       6     return f"Hello World from rank {comm.Get_rank()}. total ranks={comm.Get_size()}"
#       8 # request an MPI cluster with 4 engines
# ----> 9 with ipp.Cluster(engines='mpi', n=4) as rc:
#      10     # get a broadcast_view on the cluster which is best
#      11     # suited for MPI style computation
#      12     view = rc.broadcast_view()
#      13     # run the mpi_example function on all engines in parallel
#
# File /opt/conda/envs/conda_container_env/lib/python3.13/site-packages/ipyparallel/cluster/cluster.py:909, in Cluster.__enter__(self)
#     908 def __enter__(self):
# --> 909     client = self._context_client = self.start_and_connect_sync()
#     910     return client
#
# File /opt/conda/envs/conda_container_env/lib/python3.13/site-packages/ipyparallel/_async.py:73, in AsyncFirst._synchronize(self, async_f, *args, **kwargs)
#      71     loop = None
#      72 if loop:
# ---> 73     return self._in_thread(async_f, *args, **kwargs)
#      74 else:
#      75     return _asyncio_run(async_f(*args, **kwargs))
#
# File /opt/conda/envs/conda_container_env/lib/python3.13/site-packages/ipyparallel/_async.py:59, in AsyncFirst._in_thread(self, async_f, *args, **kwargs)
#      56         future.set_exception(e)
#      58 self._thread_loop.add_callback(thread_callback)
# ---> 59 return future.result()
#
# File /opt/conda/envs/conda_container_env/lib/python3.13/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /opt/conda/envs/conda_container_env/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/conda/envs/conda_container_env/lib/python3.13/site-packages/ipyparallel/_async.py:54, in AsyncFirst._in_thread.<locals>.thread_callback()
#      52 async def thread_callback():
#      53     try:
# ---> 54         future.set_result(await async_f(*args, **kwargs))
#      55     except Exception as e:
#      56         future.set_exception(e)
#
# File /opt/conda/envs/conda_container_env/lib/python3.13/site-packages/ipyparallel/cluster/cluster.py:759, in Cluster.start_and_connect(self, n, activate)
#     756     n = sum(engine_set.n for engine_set in self.engines.values())
#     758 if n:
# --> 759     await asyncio.wrap_future(
#     760         client.wait_for_engines(n, block=False, timeout=self.engine_timeout)
#     761     )
#     763 if activate:
#     764     view = client[:]
#
# TimeoutError: 4 engines not ready in 60 seconds. Currently ready: 0
